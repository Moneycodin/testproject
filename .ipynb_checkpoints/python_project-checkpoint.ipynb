# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:/Users/manme/OneDrive/Desktop/PROJECTS/WORLDUNIVERSITYRANK/2023_rankings.csv")
df
# Out:
#       rank_order      rank                                   name  \
# 0             10         1                   University of Oxford
# 1             20         2                     Harvard University
# 2             30        =3                University of Cambridge
# 3             40        =3                    Stanford University
# 4             50         5  Massachusetts Institute of Technology
# ...          ...       ...                                    ...
# 2340     1000523  Reporter                York St John University
# 2341     1000524  Reporter    Yusuf Maitama Sule University, Kano
# 2342     1000525  Reporter  Zhytomyr Polytechnic State University
# 2343     1000526  Reporter                    Ziauddin University
# 2344     1000544  Reporter                       Zarqa University
#
#      scores_overall  scores_overall_rank  scores_teaching  \
# 0              96.4                   10             92.3
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#       rank_order   rank                                               name  \
# 0             10      1                               University of Oxford
# 1             20      2                                 Harvard University
# 2             30     =3                            University of Cambridge
# 3             40     =3                                Stanford University
# 4             50      5              Massachusetts Institute of Technology
# ...          ...    ...                                                ...
# 1794       17950  1501+                               Yamaguchi University
# 1795       17960  1501+                                 Yanshan University
# 1796       17970  1501+                                Yeditepe University
# 1797       17980  1501+  Yuri Gagarin State Technical University of Sar...
# 1798       17990  1501+                 Zonguldak Bülent Ecevit University
#
#      scores_overall  scores_overall_rank  scores_teaching  \
# ...

# %%
df['economics']=df['subjects_offered'].str.contains('Economics')
economics_2023_universities=df[df['economics']]
top_economics_universities_2023=economics_2023_universities.sort_values(by='rank_order')[:10]
top_economics_universities_2023[['name','rank']]
# Out:
#                                      name rank
# 0                    University of Oxford    1
# 1                      Harvard University    2
# 2                 University of Cambridge   =3
# 3                     Stanford University   =3
# 4   Massachusetts Institute of Technology    5
# 5      California Institute of Technology    6
# 6                    Princeton University    7
# 7      University of California, Berkeley    8
# 8                         Yale University    9
# 11                             ETH Zurich  =11
